# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# Load specific forecasting tools
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse

# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# Load datasets
df = pd.read_csv('Brazil Mobility Transit Station.csv', index_col=0, parse_dates=True)
df.index.freq = 'D'
df.head()
# Out:
#             Cases  Mobility: Transit Stations
# Date
# 2020-03-04      1                           7
# 2020-03-05      4                          10
# 2020-03-06      6                          13
# 2020-03-07      6                           8
# 2020-03-08      6                           2

# %%
title = 'Mobility: Transit Stations vs. COVID Cases per day'
ylabel='Number of Cases'
xlabel=''

ax = df['Cases'].plot(figsize=(12,5),title=title,legend=True)
ax.autoscale(axis='x',tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
df['Mobility: Transit Stations'].plot(legend=True);

# %%
def adf_test(series,title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(),autolag='AIC') # .dropna() handles differenced data
    
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)

    for key,val in result[4].items():
        out[f'critical value ({key})']=val
        
    print(out.to_string())          # .to_string() removes the line "dtype: float64"
    
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non-stationary")

# %%
adf_test(df['Cases'],title='Cases')
# Out:
# Augmented Dickey-Fuller Test: Cases
# ADF test statistic       -1.581012
# p-value                   0.493124
# # lags used              15.000000
# # observations          228.000000
# critical value (1%)      -3.459361
# critical value (5%)      -2.874302
# critical value (10%)     -2.573571
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary

# %%
adf_test(df['Mobility: Transit Stations'], title='Mobility')
# Out:
# Augmented Dickey-Fuller Test: Mobility
# ADF test statistic       -2.293757
# p-value                   0.173989
# # lags used              14.000000
# # observations          229.000000
# critical value (1%)      -3.459233
# critical value (5%)      -2.874245
# critical value (10%)     -2.573541
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary

# %%
df_transformed = df.diff()

# %%
df_transformed = df_transformed.dropna()
adf_test(df_transformed['Cases'], title='CasesFirstDiff')
print()
adf_test(df_transformed['Mobility: Transit Stations'], title='MobilityFirstDiff')
# Out:
# Augmented Dickey-Fuller Test: CasesFirstDiff
# ADF test statistic       -4.440804
# p-value                   0.000251
# # lags used              15.000000
# # observations          227.000000
# critical value (1%)      -3.459490
# critical value (5%)      -2.874358
# critical value (10%)     -2.573602
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
# Augmented Dickey-Fuller Test: MobilityFirstDiff
# ADF test statistic       -4.297618
# p-value                   0.000448
# # lags used              13.000000
# # observations          229.000000
# critical value (1%)      -3.459233
# critical value (5%)      -2.874245
# critical value (10%)     -2.573541
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
df_transformed = df_transformed.diff().dropna()
adf_test(df_transformed['Cases'], title='CasesSecondDiff')
print()
adf_test(df_transformed['Mobility: Transit Stations'], title='MobilitySecondDiff')
# Out:
# Augmented Dickey-Fuller Test: CasesSecondDiff
# ADF test statistic     -9.559166e+00
# p-value                 2.452263e-16
# # lags used             1.300000e+01
# # observations          2.280000e+02
# critical value (1%)    -3.459361e+00
# critical value (5%)    -2.874302e+00
# critical value (10%)   -2.573571e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
# Augmented Dickey-Fuller Test: MobilitySecondDiff
# ADF test statistic     -7.048641e+00
# p-value                 5.600927e-10
# # lags used             1.500000e+01
# # observations          2.260000e+02
# critical value (1%)    -3.459620e+00
# critical value (5%)    -2.874415e+00
# critical value (10%)   -2.573632e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
nobs=7
train, test = df_transformed[0:-nobs], df_transformed[-nobs:]

# %%
from statsmodels.tsa.api import VAR
for i in range(31):
    model = VAR(train)
    results = model.fit(i)
    print('Order =', i)
    print('AIC: ', results.aic)
    print('BIC: ', results.bic)
    print()
# Out:
# Order = 0
# AIC:  23.809478458753258
# BIC:  23.838921739724697
#
# Order = 1
# AIC:  23.18380435455003
# BIC:  23.272402331866896
#
# Order = 2
# AIC:  22.755146317866892
# BIC:  22.903259556217353
#
# Order = 3
# AIC:  22.54706631321924
# BIC:  22.755059085647382
#
# Order = 4
# AIC:  22.36543426254681
# BIC:  22.633674603626428
#
# Order = 5
# AIC:  22.032388082933885
# BIC:  22.361247842917845
#
# Order = 6
# AIC:  21.395205407870563
# BIC:  21.785060307837423
#
# Order = 7
# AIC:  21.27414141940084
# BIC:  21.72537110742116
#
# Order = 8
# AIC:  21.188736062495458
# BIC:  21.701724170840688
#
# Order = 9
# AIC:  21.17893204960607
# BIC:  21.754066253023534
#
# Order = 10
# AIC:  21.17080920290502
# BIC:  21.808481277983176
#
# Order = 11
# AIC:  21.21077465322904
# BIC:  21.911380538877847
#
# Order = 12
# AIC:  21.23423372081322
# BIC:  21.998173579884995
#
# Order = 13
# AIC:  21.172181770377893
# BIC:  21.999860052454935
#
# Order = 14
# AIC:  21.115042615794327
# BIC:  22.006868121170026
#
# Order = 15
# AIC:  21.140547442263056
# BIC:  22.096933387144176
#
# Order = 16
# AIC:  21.110471072421337
# BIC:  22.131835155379733
#
# Order = 17
# AIC:  21.079882526725257
# BIC:  22.166646996428177
#
# Order = 18
# AIC:  21.11199422282034
# BIC:  22.26458594706916
#
# Order = 19
# AIC:  21.129533231644423
# BIC:  22.348383767752594
#
# Order = 20
# AIC:  21.07652881844492
# BIC:  22.362074484986636
#
# Order = 21
# AIC:  21.048940338223503
# BIC:  22.401622288185557
#
# Order = 22
# AIC:  21.029363620327867
# BIC:  22.449627915698045
#
# Order = 23
# AIC:  21.044656302643403
# BIC:  22.53295399046967
#
# Order = 24
# AIC:  21.063466356589995
# BIC:  22.620253546545705
#
# Order = 25
# AIC:  21.093605041955815
# BIC:  22.719342985447156
#
# Order = 26
# AIC:  21.107396172256458
# BIC:  22.802551343109425
#
# Order = 27
# AIC:  21.12394510217717
# BIC:  22.88898927894229
#
# Order = 28
# AIC:  21.15755116784706
# BIC:  22.99296151776132
#
# Order = 29
# AIC:  21.194157998332155
# BIC:  23.100417162978616
#
# Order = 30
# AIC:  21.195123787225935
# BIC:  23.172719969932693

# %%
results = model.fit(6)
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 02, Dec, 2020
# Time:                     15:13:30
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    21.7851
# Nobs:                     229.000    HQIC:                   21.5525
# Log likelihood:          -3073.62    FPE:                1.95851e+09
# AIC:                      21.3952    Det(Omega_mle):     1.75374e+09
# --------------------------------------------------------------------
# Results for equation Cases
# ================================================================================================
#                                    coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------
# const                                10.845237       491.928234            0.022           0.982
# L1.Cases                             -1.047987         0.052329          -20.027           0.000
# L1.Mobility: Transit Stations       231.617670        85.107394            2.721           0.006
# L2.Cases                             -1.030076         0.059054          -17.443           0.000
# L2.Mobility: Transit Stations       -56.562411       140.213193           -0.403           0.687
# L3.Cases                             -1.005957         0.067207          -14.968           0.000
# L3.Mobility: Transit Stations      -309.193765       166.859504           -1.853           0.064
# L4.Cases                             -0.894190         0.067444          -13.258           0.000
# L4.Mobility: Transit Stations      -378.115576       166.356660           -2.273           0.023
# L5.Cases                             -0.919203         0.060576          -15.174           0.000
# L5.Mobility: Transit Stations      -402.638562       136.874330           -2.942           0.003
# L6.Cases                             -0.622793         0.051933          -11.992           0.000
# L6.Mobility: Transit Stations      -252.958128        84.595346           -2.990           0.003
# ================================================================================================
#
# Results for equation Mobility: Transit Stations
# ================================================================================================
#                                    coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------
# const                                -0.013530         0.377136           -0.036           0.971
# L1.Cases                              0.000080         0.000040            1.989           0.047
# L1.Mobility: Transit Stations        -1.341700         0.065248          -20.563           0.000
# L2.Cases                              0.000143         0.000045            3.156           0.002
# L2.Mobility: Transit Stations        -1.383467         0.107494          -12.870           0.000
# L3.Cases                              0.000176         0.000052            3.407           0.001
# L3.Mobility: Transit Stations        -1.171356         0.127923           -9.157           0.000
# L4.Cases                              0.000209         0.000052            4.038           0.000
# L4.Mobility: Transit Stations        -0.848338         0.127537           -6.652           0.000
# L5.Cases                              0.000097         0.000046            2.085           0.037
# L5.Mobility: Transit Stations        -0.567892         0.104935           -5.412           0.000
# L6.Cases                             -0.000004         0.000040           -0.110           0.913
# L6.Mobility: Transit Stations        -0.346753         0.064855           -5.347           0.000
# ================================================================================================
#
# Correlation matrix of residuals
#                                  Cases  Mobility: Transit Stations
# Cases                         1.000000                    0.167672
# Mobility: Transit Stations    0.167672                    1.000000

# %%
lag_order = results.k_ar
lag_order
# Out:
# 6

# %%
z = results.forecast(y=train.values[-lag_order:], steps=7)
z
# Out:
# array([[ 6.28660800e+03,  1.78317051e+00],
#        [-5.91753896e+03, -3.61705059e+00],
#        [-2.38305393e+03,  3.33771423e-01],
#        [ 3.71680554e+03,  3.16025053e+00],
#        [-8.87950840e+03, -1.71182931e+00],
#        [-4.95016918e+03, -5.18290379e+00],
#        [ 1.30595864e+04,  4.65031891e+00]])

# %%
test
# Out:
#               Cases  Mobility: Transit Stations
# Date
# 2020-10-27  11828.0                         0.0
# 2020-10-28 -15219.0                        -2.0
# 2020-10-29  -1365.0                         1.0
# 2020-10-30  -1301.0                        -1.0
# 2020-10-31    489.0                         7.0
# 2020-11-01  -5512.0                       -16.0
# 2020-11-02   7248.0                       -19.0

# %%
idx = pd.date_range('27/10/2020', periods=7, freq='D')
df_forecast = pd.DataFrame(z, index=idx, columns=['Cases2d','Mobility2d'])
df_forecast
# Out:
#                  Cases2d  Mobility2d
# 2020-10-27   6286.607998    1.783171
# 2020-10-28  -5917.538962   -3.617051
# 2020-10-29  -2383.053926    0.333771
# 2020-10-30   3716.805544    3.160251
# 2020-10-31  -8879.508401   -1.711829
# 2020-11-01  -4950.169181   -5.182904
# 2020-11-02  13059.586411    4.650319

# %%
# Add the most recent first difference from the training side of the original dataset to the forecast cumulative sum
df_forecast['Cases1d'] = (df['Cases'].iloc[-nobs-1]-df['Cases'].iloc[-nobs-2]) + df_forecast['Cases2d'].cumsum()

# Now build the forecast values from the first difference set
df_forecast['CasesForecast'] = df['Cases'].iloc[-nobs-1] + df_forecast['Cases1d'].cumsum()

# %%
# Add the most recent first difference from the training side of the original dataset to the forecast cumulative sum
df_forecast['Mobility1d'] = (df['Mobility: Transit Stations'].iloc[-nobs-1]-df['Mobility: Transit Stations'].iloc[-nobs-2]) + df_forecast['Mobility2d'].cumsum()

# Now build the forecast values from the first difference set
df_forecast['MobilityForecast'] = df['Mobility: Transit Stations'].iloc[-nobs-1] + df_forecast['Mobility1d'].cumsum()

# %%
df_forecast
# Out:
#                  Cases2d  Mobility2d      Cases1d  CasesForecast  Mobility1d  \
# 2020-10-27   6286.607998    1.783171  8519.607998   24245.607998    2.783171
# 2020-10-28  -5917.538962   -3.617051  2602.069036   26847.677034   -0.833880
# 2020-10-29  -2383.053926    0.333771   219.015110   27066.692143   -0.500109
# 2020-10-30   3716.805544    3.160251  3935.820653   31002.512797    2.660142
# 2020-10-31  -8879.508401   -1.711829 -4943.687748   26058.825049    0.948313
# 2020-11-01  -4950.169181   -5.182904 -9893.856929   16164.968120   -4.234591
# 2020-11-02  13059.586411    4.650319  3165.729482   19330.697602    0.415728
#
#             MobilityForecast
# 2020-10-27         -9.216829
# 2020-10-28        -10.050710
# 2020-10-29        -10.550818
# 2020-10-30         -7.890676
# 2020-10-31         -6.942364
# 2020-11-01        -11.176955
# 2020-11-02        -10.761227

# %%
df['Cases'][-nobs:].plot(figsize=(12,5),legend=True).autoscale(axis='x',tight=True)
df_forecast['CasesForecast'].plot(legend=True);
