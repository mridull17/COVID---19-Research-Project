# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# Load specific forecasting tools
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse

# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# Load datasets
df = pd.read_csv('Brazil Stringency Index.csv', index_col=0, parse_dates=True)
df.index.freq = 'D'
df.head()
# Out:
#             Cases  Stringency Index
# Date
# 2020-03-04      1             11.11
# 2020-03-05      4             11.11
# 2020-03-06      6             11.11
# 2020-03-07      6             11.11
# 2020-03-08      6             11.11

# %%
title = 'Stringency Index vs. COVID Cases per day'
ylabel='Number of Cases'
xlabel=''

ax = df['Cases'].plot(figsize=(12,5),title=title,legend=True)
ax.autoscale(axis='x',tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
df['Stringency Index'].plot(legend=True);

# %%
def adf_test(series,title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(),autolag='AIC') # .dropna() handles differenced data
    
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)

    for key,val in result[4].items():
        out[f'critical value ({key})']=val
        
    print(out.to_string())          # .to_string() removes the line "dtype: float64"
    
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non-stationary")

# %%
adf_test(df['Cases'],title='Cases')
# Out:
# Augmented Dickey-Fuller Test: Cases
# ADF test statistic       -1.599762
# p-value                   0.483713
# # lags used              15.000000
# # observations          223.000000
# critical value (1%)      -3.460019
# critical value (5%)      -2.874590
# critical value (10%)     -2.573725
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary

# %%
adf_test(df['Stringency Index'], title='Stringency')
# Out:
# Augmented Dickey-Fuller Test: Stringency
# ADF test statistic     -5.750479e+00
# p-value                 5.982680e-07
# # lags used             4.000000e+00
# # observations          2.340000e+02
# critical value (1%)    -3.458608e+00
# critical value (5%)    -2.873972e+00
# critical value (10%)   -2.573396e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
df_transformed = df.diff()

# %%
df_transformed = df_transformed.dropna()
adf_test(df_transformed['Cases'], title='CasesFirstDiff')
print()
adf_test(df_transformed['Stringency Index'], title='StringencyFirstDiff')
# Out:
# Augmented Dickey-Fuller Test: CasesFirstDiff
# ADF test statistic       -4.374115
# p-value                   0.000330
# # lags used              15.000000
# # observations          222.000000
# critical value (1%)      -3.460154
# critical value (5%)      -2.874649
# critical value (10%)     -2.573757
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
# Augmented Dickey-Fuller Test: StringencyFirstDiff
# ADF test statistic       -5.073139
# p-value                   0.000016
# # lags used               3.000000
# # observations          234.000000
# critical value (1%)      -3.458608
# critical value (5%)      -2.873972
# critical value (10%)     -2.573396
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
df_transformed = df_transformed.diff().dropna()
adf_test(df_transformed['Cases'], title='CasesSecondDiff')
print()
adf_test(df_transformed['Stringency Index'], title='StringencySecondDiff')
# Out:
# Augmented Dickey-Fuller Test: CasesSecondDiff
# ADF test statistic     -9.535025e+00
# p-value                 2.823810e-16
# # lags used             1.300000e+01
# # observations          2.230000e+02
# critical value (1%)    -3.460019e+00
# critical value (5%)    -2.874590e+00
# critical value (10%)   -2.573725e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
# Augmented Dickey-Fuller Test: StringencySecondDiff
# ADF test statistic     -7.515794e+00
# p-value                 3.906550e-11
# # lags used             1.300000e+01
# # observations          2.230000e+02
# critical value (1%)    -3.460019e+00
# critical value (5%)    -2.874590e+00
# critical value (10%)   -2.573725e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
nobs=7
train, test = df_transformed[0:-nobs], df_transformed[-nobs:]

# %%
from statsmodels.tsa.api import VAR
for i in range(31):
    model = VAR(train)
    results = model.fit(i)
    print('Order =', i)
    print('AIC: ', results.aic)
    print('BIC: ', results.bic)
    print()
# Out:
# Order = 0
# AIC:  20.88503056125393
# BIC:  20.914926903070654
#
# Order = 1
# AIC:  20.577505397258523
# BIC:  20.66747191263549
#
# Order = 2
# AIC:  20.412400623016588
# BIC:  20.562810519023362
#
# Order = 3
# AIC:  20.247093969200247
# BIC:  20.458324366754166
#
# Order = 4
# AIC:  20.15545307835659
# BIC:  20.427885069449072
#
# Order = 5
# AIC:  19.88139597137741
# BIC:  20.215414677370735
#
# Order = 6
# AIC:  19.331891293224928
# BIC:  19.727885924243814
#
# Order = 7
# AIC:  18.675624613484132
# BIC:  19.133988528927198
#
# Order = 8
# AIC:  18.4858193700237
# BIC:  19.006950140220354
#
# Order = 9
# AIC:  18.509040478683755
# BIC:  19.093339947723006
#
# Order = 10
# AIC:  18.50280004579383
# BIC:  19.150674395552006
#
# Order = 11
# AIC:  18.418288067891215
# BIC:  19.13014788328646
#
# Order = 12
# AIC:  18.158491196149015
# BIC:  18.9347515316511
#
# Order = 13
# AIC:  18.090410657888423
# BIC:  18.93149110531324
#
# Order = 14
# AIC:  17.95443622765736
# BIC:  18.860760985276258
#
# Order = 15
# AIC:  17.923860026131905
# BIC:  18.895857969126858
#
# Order = 16
# AIC:  17.945665534940133
# BIC:  18.98377028723659
#
# Order = 17
# AIC:  17.828551737431752
# BIC:  18.933201744941893
#
# Order = 18
# AIC:  17.816564463418935
# BIC:  18.98820306872898
#
# Order = 19
# AIC:  17.84272298546683
# BIC:  19.081798504003004
#
# Order = 20
# AIC:  17.851735591630867
# BIC:  19.15870138933959
#
# Order = 21
# AIC:  17.823051685444348
# BIC:  19.19836625802317
#
# Order = 22
# AIC:  17.779667616329483
# BIC:  19.2237946700464
#
# Order = 23
# AIC:  17.773454852794014
# BIC:  19.28686338693384
#
# Order = 24
# AIC:  17.76732403489463
# BIC:  19.3504884258722
#
# Order = 25
# AIC:  17.772124136954165
# BIC:  19.425524224135227
#
# Order = 26
# AIC:  17.810932115493518
# BIC:  19.535053288765514
#
# Order = 27
# AIC:  17.853840977023424
# BIC:  19.64917426615937
#
# Order = 28
# AIC:  17.879563622149764
# BIC:  19.746605788009852
#
# Order = 29
# AIC:  17.880430364961523
# BIC:  19.819683992578295
#
# Order = 30
# AIC:  17.91208707185895
# BIC:  19.92406066545325

# %%
results = model.fit(8)
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 02, Dec, 2020
# Time:                     18:31:52
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    19.0070
# Nobs:                     222.000    HQIC:                   18.6962
# Log likelihood:          -2647.93    FPE:                1.06795e+08
# AIC:                      18.4858    Det(Omega_mle):     9.21426e+07
# --------------------------------------------------------------------
# Results for equation Cases
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      62.403600       469.916700            0.133           0.894
# L1.Cases                   -1.354026         0.065742          -20.596           0.000
# L1.Stringency Index       458.535185       339.898001            1.349           0.177
# L2.Cases                   -1.684459         0.100683          -16.730           0.000
# L2.Stringency Index       262.085536       356.676290            0.735           0.462
# L3.Cases                   -1.755084         0.114227          -15.365           0.000
# L3.Stringency Index        50.891000       367.490716            0.138           0.890
# L4.Cases                   -1.682559         0.113573          -14.815           0.000
# L4.Stringency Index       400.755819       407.280735            0.984           0.325
# L5.Cases                   -1.764938         0.114177          -15.458           0.000
# L5.Stringency Index       436.666570       392.135030            1.114           0.265
# L6.Cases                   -1.510546         0.114967          -13.139           0.000
# L6.Stringency Index       -54.222832       347.359049           -0.156           0.876
# L7.Cases                   -0.814668         0.101141           -8.055           0.000
# L7.Stringency Index       379.368240       320.635439            1.183           0.237
# L8.Cases                   -0.362933         0.065500           -5.541           0.000
# L8.Stringency Index       169.343218       260.285673            0.651           0.515
# ======================================================================================
#
# Results for equation Stringency Index
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -0.116154         0.092849           -1.251           0.211
# L1.Cases                    0.000011         0.000013            0.871           0.384
# L1.Stringency Index        -0.925489         0.067159          -13.781           0.000
# L2.Cases                    0.000028         0.000020            1.423           0.155
# L2.Stringency Index        -0.690528         0.070474           -9.798           0.000
# L3.Cases                    0.000038         0.000023            1.679           0.093
# L3.Stringency Index        -0.732143         0.072611          -10.083           0.000
# L4.Cases                    0.000035         0.000022            1.539           0.124
# L4.Stringency Index        -0.508114         0.080473           -6.314           0.000
# L5.Cases                    0.000039         0.000023            1.730           0.084
# L5.Stringency Index        -0.122531         0.077480           -1.581           0.114
# L6.Cases                    0.000044         0.000023            1.940           0.052
# L6.Stringency Index        -0.134129         0.068633           -1.954           0.051
# L7.Cases                    0.000034         0.000020            1.719           0.086
# L7.Stringency Index        -0.090970         0.063353           -1.436           0.151
# L8.Cases                    0.000018         0.000013            1.361           0.173
# L8.Stringency Index        -0.010566         0.051429           -0.205           0.837
# ======================================================================================
#
# Correlation matrix of residuals
#                        Cases  Stringency Index
# Cases               1.000000         -0.105823
# Stringency Index   -0.105823          1.000000

# %%
lag_order = results.k_ar
lag_order
# Out:
# 8

# %%
z = results.forecast(y=train.values[-lag_order:], steps=7)
z
# Out:
# array([[ 4.46207146e+03, -2.26660778e-01],
#        [-1.24266841e+03, -1.88140725e-01],
#        [-1.50508910e+04,  3.18466155e-01],
#        [ 1.25564846e+03,  1.60355412e-01],
#        [ 1.22991837e+04, -1.37826587e-01],
#        [ 2.04184068e+03, -3.22632000e-01],
#        [-1.12005022e+03, -5.52308087e-02]])

# %%
test
# Out:
#               Cases  Stringency Index
# Date
# 2020-10-22  -1551.0              0.00
# 2020-10-23   5128.0             -5.56
# 2020-10-24  -8215.0              5.56
# 2020-10-25 -10439.0             -2.78
# 2020-10-26  15719.0              2.78
# 2020-10-27  11828.0              0.00
# 2020-10-28 -15219.0              0.00

# %%
idx = pd.date_range('22/10/2020', periods=7, freq='D')
df_forecast = pd.DataFrame(z, index=idx, columns=['Cases2d','Stringency2d'])
df_forecast
# Out:
#                  Cases2d  Stringency2d
# 2020-10-22   4462.071461     -0.226661
# 2020-10-23  -1242.668406     -0.188141
# 2020-10-24 -15050.891020      0.318466
# 2020-10-25   1255.648456      0.160355
# 2020-10-26  12299.183733     -0.137827
# 2020-10-27   2041.840676     -0.322632
# 2020-10-28  -1120.050221     -0.055231

# %%
# Add the most recent first difference from the training side of the original dataset to the forecast cumulative sum
df_forecast['Cases1d'] = (df['Cases'].iloc[-nobs-1]-df['Cases'].iloc[-nobs-2]) + df_forecast['Cases2d'].cumsum()

# Now build the forecast values from the first difference set
df_forecast['CasesForecast'] = df['Cases'].iloc[-nobs-1] + df_forecast['Cases1d'].cumsum()

# %%
# Add the most recent first difference from the training side of the original dataset to the forecast cumulative sum
df_forecast['Stringency1d'] = (df['Stringency Index'].iloc[-nobs-1]-df['Stringency Index'].iloc[-nobs-2]) + df_forecast['Stringency2d'].cumsum()

# Now build the forecast values from the first difference set
df_forecast['StringencyForecast'] = df['Stringency Index'].iloc[-nobs-1] + df_forecast['Stringency1d'].cumsum()

# %%
df_forecast
# Out:
#                  Cases2d  Stringency2d       Cases1d  CasesForecast  \
# 2020-10-22   4462.071461     -0.226661   6053.071461   30871.071461
# 2020-10-23  -1242.668406     -0.188141   4810.403055   35681.474516
# 2020-10-24 -15050.891020      0.318466 -10240.487965   25440.986551
# 2020-10-25   1255.648456      0.160355  -8984.839509   16456.147042
# 2020-10-26  12299.183733     -0.137827   3314.344224   19770.491266
# 2020-10-27   2041.840676     -0.322632   5356.184901   25126.676166
# 2020-10-28  -1120.050221     -0.055231   4236.134680   29362.810846
#
#             Stringency1d  StringencyForecast
# 2020-10-22     -0.226661           63.203339
# 2020-10-23     -0.414802           62.788538
# 2020-10-24     -0.096335           62.692202
# 2020-10-25      0.064020           62.756222
# 2020-10-26     -0.073807           62.682416
# 2020-10-27     -0.396439           62.285977
# 2020-10-28     -0.451669           61.834308

# %%
df['Cases'][-nobs:].plot(figsize=(12,5),legend=True).autoscale(axis='x',tight=True)
df_forecast['CasesForecast'].plot(legend=True);
