# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# Load specific forecasting tools
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse

# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# Load datasets
df = pd.read_csv('US Mobility Transit Stations.csv', index_col=0, parse_dates=True)
df.index.freq = 'D'
df.head()
# Out:
#             Cases  Mobility: Transit Stations
# Date
# 2020-03-01     20                           7
# 2020-03-02     14                           2
# 2020-03-03     22                           3
# 2020-03-04     34                           2
# 2020-03-05     74                           2

# %%
title = 'Mobility: Transit Stations vs. COVID Cases per day'
ylabel='Number of Cases'
xlabel=''

ax = df['Cases'].plot(figsize=(12,5),title=title,legend=True)
ax.autoscale(axis='x',tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
df['Mobility: Transit Stations'].plot(legend=True);

# %%
def adf_test(series,title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(),autolag='AIC') # .dropna() handles differenced data
    
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)

    for key,val in result[4].items():
        out[f'critical value ({key})']=val
        
    print(out.to_string())          # .to_string() removes the line "dtype: float64"
    
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non-stationary")

# %%
adf_test(df['Cases'],title='Cases')
# Out:
# Augmented Dickey-Fuller Test: Cases
# ADF test statistic       -1.238645
# p-value                   0.656755
# # lags used              13.000000
# # observations          233.000000
# critical value (1%)      -3.458731
# critical value (5%)      -2.874026
# critical value (10%)     -2.573424
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary

# %%
adf_test(df['Mobility: Transit Stations'], title='Mobility')
# Out:
# Augmented Dickey-Fuller Test: Mobility
# ADF test statistic       -3.178406
# p-value                   0.021269
# # lags used              14.000000
# # observations          232.000000
# critical value (1%)      -3.458855
# critical value (5%)      -2.874080
# critical value (10%)     -2.573453
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
df_transformed = df.diff()

# %%
df_transformed = df_transformed.dropna()
adf_test(df_transformed['Cases'], title='CasesFirstDiff')
print()
adf_test(df_transformed['Mobility: Transit Stations'], title='MobilityFirstDiff')
# Out:
# Augmented Dickey-Fuller Test: CasesFirstDiff
# ADF test statistic       -2.772410
# p-value                   0.062324
# # lags used              12.000000
# # observations          233.000000
# critical value (1%)      -3.458731
# critical value (5%)      -2.874026
# critical value (10%)     -2.573424
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary
#
# Augmented Dickey-Fuller Test: MobilityFirstDiff
# ADF test statistic       -3.582097
# p-value                   0.006113
# # lags used              13.000000
# # observations          232.000000
# critical value (1%)      -3.458855
# critical value (5%)      -2.874080
# critical value (10%)     -2.573453
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
df_transformed = df_transformed.diff().dropna()
adf_test(df_transformed['Cases'], title='CasesSecondDiff')
print()
adf_test(df_transformed['Mobility: Transit Stations'], title='MobilitySecondDiff')
# Out:
# Augmented Dickey-Fuller Test: CasesSecondDiff
# ADF test statistic     -6.486413e+00
# p-value                 1.257669e-08
# # lags used             1.100000e+01
# # observations          2.330000e+02
# critical value (1%)    -3.458731e+00
# critical value (5%)    -2.874026e+00
# critical value (10%)   -2.573424e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
# Augmented Dickey-Fuller Test: MobilitySecondDiff
# ADF test statistic     -7.135559e+00
# p-value                 3.428438e-10
# # lags used             1.500000e+01
# # observations          2.290000e+02
# critical value (1%)    -3.459233e+00
# critical value (5%)    -2.874245e+00
# critical value (10%)   -2.573541e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
nobs=7
train, test = df_transformed[0:-nobs], df_transformed[-nobs:]

# %%
from statsmodels.tsa.api import VAR
for i in range(31):
    model = VAR(train)
    results = model.fit(i)
    print('Order =', i)
    print('AIC: ', results.aic)
    print('BIC: ', results.bic)
    print()
# Out:
# Order = 0
# AIC:  22.40667145014605
# BIC:  22.43585019530295
#
# Order = 1
# AIC:  21.83129063032386
# BIC:  21.919089621238673
#
# Order = 2
# AIC:  21.239276213632003
# BIC:  21.386048747743256
#
# Order = 3
# AIC:  21.158562893878283
# BIC:  21.36466586067836
#
# Order = 4
# AIC:  20.79548518469079
# BIC:  21.061279116641384
#
# Order = 5
# AIC:  20.342534821013583
# BIC:  20.668383945384594
#
# Order = 6
# AIC:  19.484116963651086
# BIC:  19.870389255303344
#
# Order = 7
# AIC:  19.25592889209235
# BIC:  19.702996127225052
#
# Order = 8
# AIC:  19.225700793375125
# BIC:  19.73393860425942
#
# Order = 9
# AIC:  19.2057911658806
# BIC:  19.775579096601394
#
# Order = 10
# AIC:  19.1961599216299
# BIC:  19.82788148485835
#
# Order = 11
# AIC:  19.187393250576772
# BIC:  19.88143598539679
#
# Order = 12
# AIC:  19.11602355252848
# BIC:  19.87277908334093
#
# Order = 13
# AIC:  19.044076016716758
# BIC:  19.863940113245818
#
# Order = 14
# AIC:  19.070227708049973
# BIC:  19.953600346476726
#
# Order = 15
# AIC:  19.100580968661614
# BIC:  20.047866393910613
#
# Order = 16
# AIC:  19.081395813172833
# BIC:  20.093002602378107
#
# Order = 17
# AIC:  19.102165985437114
# BIC:  20.17850711261468
#
# Order = 18
# AIC:  19.141318502401912
# BIC:  20.2828114043568
#
# Order = 19
# AIC:  19.170842737742294
# BIC:  20.37790938123858
#
# Order = 20
# AIC:  19.156503686057516
# BIC:  20.429570636280936
#
# Order = 21
# AIC:  19.164168490606173
# BIC:  20.503666980949397
#
# Order = 22
# AIC:  19.17877991564264
# BIC:  20.585145918844376
#
# Order = 23
# AIC:  19.203168984929018
# BIC:  20.67684328559879
#
# Order = 24
# AIC:  19.2229436856777
# BIC:  20.764371954239106
#
# Order = 25
# AIC:  19.245543916035498
# BIC:  20.855176784121703
#
# Order = 26
# AIC:  19.237117432346636
# BIC:  20.915410569682642
#
# Order = 27
# AIC:  19.28231253858705
# BIC:  21.02972673139448
#
# Order = 28
# AIC:  19.261645527450057
# BIC:  21.07864675841097
#
# Order = 29
# AIC:  19.263269836849933
# BIC:  21.150329366667386
#
# Order = 30
# AIC:  19.264322145386785
# BIC:  21.221916595980826

# %%
results = model.fit(13)
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 01, Dec, 2020
# Time:                     00:24:05
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    19.8639
# Nobs:                     225.000    HQIC:                   19.3750
# Log likelihood:          -2726.98    FPE:                1.86959e+08
# AIC:                      19.0441    Det(Omega_mle):     1.49043e+08
# --------------------------------------------------------------------
# Results for equation Cases
# =================================================================================================
#                                     coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------------
# const                                138.565883       331.344743            0.418           0.676
# L1.Cases                              -1.646303         0.071288          -23.094           0.000
# L1.Mobility: Transit Stations        299.928447       136.261705            2.201           0.028
# L2.Cases                              -2.073554         0.136737          -15.165           0.000
# L2.Mobility: Transit Stations        230.685207       218.149149            1.057           0.290
# L3.Cases                              -2.332942         0.199002          -11.723           0.000
# L3.Mobility: Transit Stations        177.911240       289.865384            0.614           0.539
# L4.Cases                              -2.372508         0.257158           -9.226           0.000
# L4.Mobility: Transit Stations       -111.287360       341.436308           -0.326           0.744
# L5.Cases                              -2.249836         0.304907           -7.379           0.000
# L5.Mobility: Transit Stations       -139.466902       375.489424           -0.371           0.710
# L6.Cases                              -1.853478         0.339047           -5.467           0.000
# L6.Mobility: Transit Stations       -116.195685       396.675977           -0.293           0.770
# L7.Cases                              -1.330950         0.353021           -3.770           0.000
# L7.Mobility: Transit Stations       -188.188152       405.023752           -0.465           0.642
# L8.Cases                              -0.687390         0.345140           -1.992           0.046
# L8.Mobility: Transit Stations       -699.126337       388.646010           -1.799           0.072
# L9.Cases                              -0.242998         0.312791           -0.777           0.437
# L9.Mobility: Transit Stations       -800.649611       365.678729           -2.189           0.029
# L10.Cases                              0.101745         0.264850            0.384           0.701
# L10.Mobility: Transit Stations      -743.276789       332.265710           -2.237           0.025
# L11.Cases                              0.251255         0.204766            1.227           0.220
# L11.Mobility: Transit Stations      -649.903437       284.188710           -2.287           0.022
# L12.Cases                              0.152187         0.140040            1.087           0.277
# L12.Mobility: Transit Stations      -450.453775       216.140975           -2.084           0.037
# L13.Cases                              0.000737         0.073483            0.010           0.992
# L13.Mobility: Transit Stations      -243.573603       137.658356           -1.769           0.077
# =================================================================================================
#
# Results for equation Mobility: Transit Stations
# =================================================================================================
#                                     coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------------
# const                                  0.080670         0.165881            0.486           0.627
# L1.Cases                               0.000016         0.000036            0.453           0.651
# L1.Mobility: Transit Stations         -1.197630         0.068217          -17.556           0.000
# L2.Cases                               0.000017         0.000068            0.246           0.806
# L2.Mobility: Transit Stations         -1.367396         0.109212          -12.521           0.000
# L3.Cases                               0.000028         0.000100            0.280           0.779
# L3.Mobility: Transit Stations         -1.351549         0.145115           -9.314           0.000
# L4.Cases                               0.000038         0.000129            0.295           0.768
# L4.Mobility: Transit Stations         -1.222113         0.170933           -7.150           0.000
# L5.Cases                              -0.000007         0.000153           -0.048           0.962
# L5.Mobility: Transit Stations         -1.055004         0.187981           -5.612           0.000
# L6.Cases                              -0.000026         0.000170           -0.155           0.877
# L6.Mobility: Transit Stations         -0.815693         0.198588           -4.107           0.000
# L7.Cases                               0.000002         0.000177            0.009           0.993
# L7.Mobility: Transit Stations         -0.233783         0.202767           -1.153           0.249
# L8.Cases                               0.000041         0.000173            0.238           0.812
# L8.Mobility: Transit Stations         -0.054435         0.194568           -0.280           0.780
# L9.Cases                               0.000049         0.000157            0.314           0.753
# L9.Mobility: Transit Stations          0.071052         0.183070            0.388           0.698
# L10.Cases                              0.000095         0.000133            0.719           0.472
# L10.Mobility: Transit Stations         0.047969         0.166342            0.288           0.773
# L11.Cases                              0.000101         0.000103            0.989           0.323
# L11.Mobility: Transit Stations        -0.012694         0.142273           -0.089           0.929
# L12.Cases                              0.000139         0.000070            1.982           0.048
# L12.Mobility: Transit Stations        -0.115165         0.108207           -1.064           0.287
# L13.Cases                              0.000080         0.000037            2.161           0.031
# L13.Mobility: Transit Stations        -0.294878         0.068916           -4.279           0.000
# =================================================================================================
#
# Correlation matrix of residuals
#                                  Cases  Mobility: Transit Stations
# Cases                         1.000000                    0.126690
# Mobility: Transit Stations    0.126690                    1.000000

# %%
lag_order = results.k_ar
lag_order
# Out:
# 13

# %%
z = results.forecast(y=train.values[-lag_order:], steps=7)
z
# Out:
# array([[ 1.19714583e+03,  6.56862868e+00],
#        [-8.01079162e+03,  5.31962684e-02],
#        [ 8.61465750e+03,  1.21405149e+00],
#        [-3.61060338e+03,  1.31039823e+00],
#        [-1.29343459e+04,  7.10041889e+00],
#        [-6.02982052e+02, -1.41663340e+01],
#        [ 6.67876203e+03, -3.70687462e+00]])

# %%
test
# Out:
#               Cases  Mobility: Transit Stations
# Date
# 2020-10-27  -2149.0                         8.0
# 2020-10-28  -3528.0                        -2.0
# 2020-10-29   6517.0                         0.0
# 2020-10-30   3384.0                         4.0
# 2020-10-31 -35482.0                         6.0
# 2020-11-01  24406.0                       -15.0
# 2020-11-02    815.0                         0.0

# %%
idx = pd.date_range('27/10/2020', periods=7, freq='D')
df_forecast = pd.DataFrame(z, index=idx, columns=['Cases2d','Mobility2d'])
df_forecast
# Out:
#                  Cases2d  Mobility2d
# 2020-10-27   1197.145831    6.568629
# 2020-10-28  -8010.791616    0.053196
# 2020-10-29   8614.657502    1.214051
# 2020-10-30  -3610.603384    1.310398
# 2020-10-31 -12934.345945    7.100419
# 2020-11-01   -602.982052  -14.166334
# 2020-11-02   6678.762028   -3.706875

# %%
# Add the most recent first difference from the training side of the original dataset to the forecast cumulative sum
df_forecast['Cases1d'] = (df['Cases'].iloc[-nobs-1]-df['Cases'].iloc[-nobs-2]) + df_forecast['Cases2d'].cumsum()

# Now build the forecast values from the first difference set
df_forecast['CasesForecast'] = df['Cases'].iloc[-nobs-1] + df_forecast['Cases1d'].cumsum()

# %%
# Add the most recent first difference from the training side of the original dataset to the forecast cumulative sum
df_forecast['Mobility1d'] = (df['Mobility: Transit Stations'].iloc[-nobs-1]-df['Mobility: Transit Stations'].iloc[-nobs-2]) + df_forecast['Mobility2d'].cumsum()

# Now build the forecast values from the first difference set
df_forecast['MobilityForecast'] = df['Mobility: Transit Stations'].iloc[-nobs-1] + df_forecast['Mobility1d'].cumsum()

# %%
df_forecast
# Out:
#                  Cases2d  Mobility2d       Cases1d  CasesForecast  Mobility1d  \
# 2020-10-27   1197.145831    6.568629  10116.145831   78475.145831   -0.431371
# 2020-10-28  -8010.791616    0.053196   2105.354214   80580.500045   -0.378175
# 2020-10-29   8614.657502    1.214051  10720.011716   91300.511761    0.835876
# 2020-10-30  -3610.603384    1.310398   7109.408332   98409.920093    2.146275
# 2020-10-31 -12934.345945    7.100419  -5824.937613   92584.982480    9.246694
# 2020-11-01   -602.982052  -14.166334  -6427.919665   86157.062815   -4.919640
# 2020-11-02   6678.762028   -3.706875    250.842363   86407.905179   -8.626515
#
#             MobilityForecast
# 2020-10-27        -34.431371
# 2020-10-28        -34.809546
# 2020-10-29        -33.973670
# 2020-10-30        -31.827395
# 2020-10-31        -22.580702
# 2020-11-01        -27.500342
# 2020-11-02        -36.126857

# %%
df['Cases'][-nobs:].plot(figsize=(12,5),legend=True).autoscale(axis='x',tight=True)
df_forecast['CasesForecast'].plot(legend=True);
