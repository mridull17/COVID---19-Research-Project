# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# Load specific forecasting tools
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse

# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# Load datasets
df = pd.read_csv('India_temp.csv', index_col=0, parse_dates=True)
df.index.freq = 'D'
df.head()
# Out:
#             Cases  Temperature
# Date
# 2020-03-02      2    24.215278
# 2020-03-03      1    24.361111
# 2020-03-04     22    24.187500
# 2020-03-05      1    23.694444
# 2020-03-06      2    23.437500

# %%
title = 'Temperature vs. COVID Cases per day'
ylabel='Number of Cases'
xlabel=''

ax = df['Cases'].plot(figsize=(12,5),title=title,legend=True)
ax.autoscale(axis='x',tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
df['Temperature'].plot(legend=True);

# %%
def adf_test(series,title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(),autolag='AIC') # .dropna() handles differenced data
    
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)

    for key,val in result[4].items():
        out[f'critical value ({key})']=val
        
    print(out.to_string())          # .to_string() removes the line "dtype: float64"
    
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non-stationary")

# %%
adf_test(df['Cases'],title='Cases')
# Out:
# Augmented Dickey-Fuller Test: Cases
# ADF test statistic       -1.763322
# p-value                   0.398817
# # lags used              15.000000
# # observations          230.000000
# critical value (1%)      -3.459106
# critical value (5%)      -2.874190
# critical value (10%)     -2.573512
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary

# %%
adf_test(df['Temperature'], title='Temperature')
# Out:
# Augmented Dickey-Fuller Test: Temperature
# ADF test statistic       -3.452344
# p-value                   0.009299
# # lags used               0.000000
# # observations          245.000000
# critical value (1%)      -3.457326
# critical value (5%)      -2.873410
# critical value (10%)     -2.573096
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
df_transformed = df.diff()

# %%
df_transformed = df_transformed.dropna()
adf_test(df_transformed['Cases'], title='CasesFirstDiff')
print()
adf_test(df_transformed['Temperature'], title='TemperatureFirstDiff')
# Out:
# Augmented Dickey-Fuller Test: CasesFirstDiff
# ADF test statistic       -2.124834
# p-value                   0.234647
# # lags used              16.000000
# # observations          228.000000
# critical value (1%)      -3.459361
# critical value (5%)      -2.874302
# critical value (10%)     -2.573571
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary
#
# Augmented Dickey-Fuller Test: TemperatureFirstDiff
# ADF test statistic     -1.549977e+01
# p-value                 2.424175e-28
# # lags used             0.000000e+00
# # observations          2.440000e+02
# critical value (1%)    -3.457438e+00
# critical value (5%)    -2.873459e+00
# critical value (10%)   -2.573122e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
df_transformed = df_transformed.diff().dropna()
adf_test(df_transformed['Cases'], title='CasesSecondDiff')
print()
adf_test(df_transformed['Temperature'], title='TemperatureSecondDiff')
# Out:
# Augmented Dickey-Fuller Test: CasesSecondDiff
# ADF test statistic       -4.347048
# p-value                   0.000368
# # lags used              15.000000
# # observations          228.000000
# critical value (1%)      -3.459361
# critical value (5%)      -2.874302
# critical value (10%)     -2.573571
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
# Augmented Dickey-Fuller Test: TemperatureSecondDiff
# ADF test statistic     -8.828920e+00
# p-value                 1.791807e-14
# # lags used             1.400000e+01
# # observations          2.290000e+02
# critical value (1%)    -3.459233e+00
# critical value (5%)    -2.874245e+00
# critical value (10%)   -2.573541e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
len(df_transformed)
# Out:
# 244

# %%
nobs=7
train, test = df_transformed[0:-nobs], df_transformed[-nobs:]

# %%
print(train.shape)
print(test.shape)
# Out:
# (237, 2)
# (7, 2)

# %%
for i in range(31):
    model = VAR(train)
    results = model.fit(i)
    print('Order =', i)
    print('AIC: ', results.aic)
    print('BIC: ', results.bic)
    print()
# Out:
# Order = 0
# AIC:  17.957822478316903
# BIC:  17.98708880862184
#
# Order = 1
# AIC:  17.666298866044254
# BIC:  17.75436238651101
#
# Order = 2
# AIC:  17.191169441879726
# BIC:  17.338385846736927
#
# Order = 3
# AIC:  17.12710761205955
# BIC:  17.3338362257989
#
# Order = 4
# AIC:  17.05372120448287
# BIC:  17.320325033513697
#
# Order = 5
# AIC:  16.928023189521557
# BIC:  17.254868974765778
#
# Order = 6
# AIC:  15.888189802109768
# BIC:  16.275648072558106
#
# Order = 7
# AIC:  15.785340430461314
# BIC:  16.233785557712167
#
# Order = 8
# AIC:  15.742564659563987
# BIC:  16.2523749133668
#
# Order = 9
# AIC:  15.752420961041645
# BIC:  16.323978565867385
#
# Order = 10
# AIC:  15.762468476379032
# BIC:  16.396159669040788
#
# Order = 11
# AIC:  15.764296114756151
# BIC:  16.460511203103607
#
# Order = 12
# AIC:  15.731906083387933
# BIC:  16.491039506100027
#
# Order = 13
# AIC:  15.723137218226963
# BIC:  16.545587605727732
#
# Order = 14
# AIC:  15.716080465504051
# BIC:  16.60225070202731
#
# Order = 15
# AIC:  15.720370401001269
# BIC:  16.670667687830463
#
# Order = 16
# AIC:  15.707112396742154
# BIC:  16.721948316652433
#
# Order = 17
# AIC:  15.725087394781827
# BIC:  16.804877977712124
#
# Order = 18
# AIC:  15.739832938597232
# BIC:  16.88499872858089
#
# Order = 19
# AIC:  15.759589965039257
# BIC:  16.97055608842251
#
# Order = 20
# AIC:  15.689139858354856
# BIC:  16.96633609333328
#
# Order = 21
# AIC:  15.702373331112748
# BIC:  17.04623417861663
#
# Order = 22
# AIC:  15.715930114160367
# BIC:  17.126894870120783
#
# Order = 23
# AIC:  15.688402709424755
# BIC:  17.166915538453043
#
# Order = 24
# AIC:  15.684928360057103
# BIC:  17.2314383705713
#
# Order = 25
# AIC:  15.720195612849057
# BIC:  17.33515693368182
#
# Order = 26
# AIC:  15.740815856448801
# BIC:  17.424687714972322
#
# Order = 27
# AIC:  15.771955265513851
# BIC:  17.52520206731824
#
# Order = 28
# AIC:  15.804148355020672
# BIC:  17.627239765183297
#
# Order = 29
# AIC:  15.821485766220384
# BIC:  17.714896792204787
#
# Order = 30
# AIC:  15.78266833877794
# BIC:  17.746879415001974

# %%
model.endog_names
# Out:
# ['Cases', 'Temperature']

# %%
results = model.fit(6)
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 10, Nov, 2020
# Time:                     07:31:25
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    16.2756
# Nobs:                     231.000    HQIC:                   16.0445
# Log likelihood:          -2464.64    FPE:                7.94798e+06
# AIC:                      15.8882    Det(Omega_mle):     7.12362e+06
# --------------------------------------------------------------------
# Results for equation Cases
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                -49.639713       147.343017           -0.337           0.736
# L1.Cases              -0.962075         0.040136          -23.970           0.000
# L1.Temperature       -62.302946       126.589506           -0.492           0.623
# L2.Cases              -1.052953         0.045608          -23.087           0.000
# L2.Temperature       150.197726       160.107311            0.938           0.348
# L3.Cases              -0.945495         0.054535          -17.337           0.000
# L3.Temperature      -141.664373       176.563376           -0.802           0.422
# L4.Cases              -0.975150         0.054792          -17.797           0.000
# L4.Temperature      -128.039431       175.992086           -0.728           0.467
# L5.Cases              -0.935697         0.046076          -20.308           0.000
# L5.Temperature        14.270712       159.551427            0.089           0.929
# L6.Cases              -0.824650         0.040559          -20.332           0.000
# L6.Temperature      -100.179430       127.206416           -0.788           0.431
# =================================================================================
#
# Results for equation Temperature
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 -0.003830         0.078451           -0.049           0.961
# L1.Cases              -0.000032         0.000021           -1.488           0.137
# L1.Temperature        -0.787911         0.067401          -11.690           0.000
# L2.Cases               0.000004         0.000024            0.166           0.868
# L2.Temperature        -0.733723         0.085247           -8.607           0.000
# L3.Cases               0.000009         0.000029            0.327           0.744
# L3.Temperature        -0.536536         0.094009           -5.707           0.000
# L4.Cases               0.000028         0.000029            0.969           0.333
# L4.Temperature        -0.438676         0.093705           -4.681           0.000
# L5.Cases               0.000009         0.000025            0.378           0.705
# L5.Temperature        -0.162710         0.084951           -1.915           0.055
# L6.Cases              -0.000001         0.000022           -0.040           0.968
# L6.Temperature        -0.098007         0.067729           -1.447           0.148
# =================================================================================
#
# Correlation matrix of residuals
#                   Cases  Temperature
# Cases          1.000000     0.022168
# Temperature    0.022168     1.000000

# %%
lag_order = results.k_ar
lag_order
# Out:
# 6

# %%
z = results.forecast(y=train.values[-lag_order:], steps=7)
z
# Out:
# array([[ 1.47248098e+04, -1.35621590e-01],
#        [-4.20901999e+03, -5.31386236e-01],
#        [-4.72706847e+03,  4.33580984e-01],
#        [ 2.07996826e+03,  2.38030972e-01],
#        [-2.46025552e+03,  3.48384997e-02],
#        [-1.99827618e+03, -1.28986703e-01],
#        [-1.16801777e+03, -2.57879806e-01]])

# %%
test
# Out:
#               Cases  Temperature
# Date
# 2020-10-27  16101.0    -0.006945
# 2020-10-28  -1435.0    -0.743055
# 2020-10-29  -7221.0    -0.157407
# 2020-10-30    853.0     0.875000
# 2020-10-31   -925.0     1.159721
# 2020-11-01   -427.0    -0.384258
# 2020-11-02  -5189.0    -0.611112

# %%
idx = pd.date_range('27/10/2020', periods=7, freq='D')
df_forecast = pd.DataFrame(z, index=idx, columns=['Cases2d','Temperature2d'])
df_forecast
# Out:
#                  Cases2d  Temperature2d
# 2020-10-27  14724.809822      -0.135622
# 2020-10-28  -4209.019992      -0.531386
# 2020-10-29  -4727.068465       0.433581
# 2020-10-30   2079.968260       0.238031
# 2020-10-31  -2460.255523       0.034838
# 2020-11-01  -1998.276184      -0.128987
# 2020-11-02  -1168.017774      -0.257880

# %%
# Add the most recent first difference from the training side of the original dataset to the forecast cumulative sum
df_forecast['Cases1d'] = (df['Cases'].iloc[-nobs-1]-df['Cases'].iloc[-nobs-2]) + df_forecast['Cases2d'].cumsum()

# Now build the forecast values from the first difference set
df_forecast['CasesForecast'] = df['Cases'].iloc[-nobs-1] + df_forecast['Cases1d'].cumsum()

# %%
# Add the most recent first difference from the training side of the original dataset to the forecast cumulative sum
df_forecast['Temperature1d'] = (df['Temperature'].iloc[-nobs-1]-df['Temperature'].iloc[-nobs-2]) + df_forecast['Temperature2d'].cumsum()

# Now build the forecast values from the first difference set
df_forecast['TemperatureForecast'] = df['Temperature'].iloc[-nobs-1] + df_forecast['Temperature1d'].cumsum()

# %%
df_forecast
# Out:
#                  Cases2d  Temperature2d      Cases1d  CasesForecast  \
# 2020-10-27  14724.809822      -0.135622  6046.809822   42516.809822
# 2020-10-28  -4209.019992      -0.531386  1837.789829   44354.599651
# 2020-10-29  -4727.068465       0.433581 -2889.278636   41465.321015
# 2020-10-30   2079.968260       0.238031  -809.310376   40656.010640
# 2020-10-31  -2460.255523       0.034838 -3269.565898   37386.444741
# 2020-11-01  -1998.276184      -0.128987 -5267.842082   32118.602659
# 2020-11-02  -1168.017774      -0.257880 -6435.859856   25682.742802
#
#             Temperature1d  TemperatureForecast
# 2020-10-27      -0.260622            25.954656
# 2020-10-28      -0.792008            25.162649
# 2020-10-29      -0.358427            24.804222
# 2020-10-30      -0.120396            24.683826
# 2020-10-31      -0.085557            24.598269
# 2020-11-01      -0.214544            24.383724
# 2020-11-02      -0.472424            23.911301

# %%
df['Cases'][-nobs:].plot(figsize=(12,5),legend=True).autoscale(axis='x',tight=True)
df_forecast['CasesForecast'].plot(legend=True);
